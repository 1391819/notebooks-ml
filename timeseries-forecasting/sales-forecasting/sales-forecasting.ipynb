# %% [markdown]
# # <div style="color:white;display:fill;border-radius:5px;background-color:#9DCDD1;overflow:hidden"><p style="padding:20px;color:white;overflow:hidden;font-size:100%;letter-spacing:0.5px;margin:0"><b>1 | About</b></div>
#
# Sale forecasting and data enrichment model.
#
# ## <div style="color:white;display:fill;border-radius:5px;background-color:#9DCDD1;overflow:hidden"><p style="padding:20px;color:white;overflow:hidden;font-size:100%;letter-spacing:0.5px;margin:0"><b>2 | Data overview</b></div>
# - Tabular data (.csv)
# - 5 years worth of product sales data
# - 4 features
#   - ["date", "store_id", "item_id", "sales"]
# - limited information (i.e., only date and sales are useful) for our model to understand how to succesfully predict future sales
# - forecast the future sales of products for the next 3 months
#
# ## <div style="color:white;display:fill;border-radius:5px;background-color:#9DCDD1;overflow:hidden"><p style="padding:20px;color:white;overflow:hidden;font-size:100%;letter-spacing:0.5px;margin:0"><b>3 | Stack</b></div>
#
# - Catboost: state-of-the-art gradient boosting on decision trees
# - Upgini: data enrichment given limited data
#   - used to automatically search through thousands of public data sources to find the most relevant features that work for the project

# %% [markdown]
# ## <div style="color:white;display:fill;border-radius:5px;background-color:#9DCDD1;overflow:hidden"><p style="padding:20px;color:white;overflow:hidden;font-size:100%;letter-spacing:0.5px;margin:0"><b>4 | Exploratory Data Analysis</b></div>

# %%
# !pip install -q upgini catboost

# %%
from os.path import exists
import pandas as pd

df_path = "train.csv.zip" if exists("train.csv.zip") else "https://github.com/upgini/upgini/raw/main/notebooks/train.csv.zip"
df = pd.read_csv(df_path)
df = df.sample(n=19_000, random_state=0)
df["store"] = df["store"].astype(str)
df["item"] = df["item"].astype(str)

# Convert date column to datetime pandas object
df["date"] = pd.to_datetime(df["date"])

df.sort_values("date", inplace=True)
df.reset_index(inplace=True, drop=True)
df.head()
# Out:
#         date store item  sales
# 0 2013-01-01     7    5      5
# 1 2013-01-01     4    9     19
# 2 2013-01-01     1   33     37
# 3 2013-01-01     3   41     14
# 4 2013-01-01     5   24     26

# %% [markdown]
# ## <div style="color:white;display:fill;border-radius:5px;background-color:#9DCDD1;overflow:hidden"><p style="padding:20px;color:white;overflow:hidden;font-size:100%;letter-spacing:0.5px;margin:0"><b>5 | Training</b></div>

# %% [markdown]
# ### <b><span style='color:#58A2A8'>5.1</span> | Creating train and test splits</b>

# %%
train = df[df["date"] < "2017-01-01"]
test = df[df["date"] >= "2017-01-01"]

# %%
train_features = train.drop(columns=["sales"])
train_target = train["sales"]
test_features = test.drop(columns=["sales"])
test_target = test["sales"]

# %% [markdown]
# ### <b><span style='color:#58A2A8'>5.2</span> | Data enrichment</b>

# %%
from upgini import FeaturesEnricher, SearchKey
from upgini.metadata import CVType

enricher = FeaturesEnricher(
    search_keys = {
      "date": SearchKey.DATE,
    },
    cv = CVType.time_series
)
enricher.fit(train_features,
             train_target,
             eval_set=[(test_features, test_target)]
)
# Out:
# WARNING: You have started the search with the DATE key only. Try to add the COUNTRY and/or POSTAL_CODE keys to your dataset so that the search engine gets access to the additional data sources. Get details on https://github.com/upgini/upgini#2--choose-one-or-multiple-columns-as-a-search-keys
# Detected task type: ModelTaskType.REGRESSION
# <table><tr><th style='font-weight:bold'>Column name</th><th style='font-weight:bold'>Status</th><th style='font-weight:bold'>Description</th></tr><tr><td>date</td><td style='background-color:#DAF7A6;color:black'>All valid</td><td>All values in this column are good to go</td></tr><tr><td>target</td><td style='background-color:#DAF7A6;color:black'>All valid</td><td>All values in this column are good to go</td></tr></table>
# Running search request with search_id=085aa5ce-17a7-4149-9263-3f41afb734b8
# We'll send email notification once it's completed, just use your personal api_key from profile.upgini.com
# Done
#
#
# 33 relevant feature(s) found with the search keys: ['date'].
#                                 feature_name  shap_value  coverage %  \
# 0                                       item    0.488097       100.0
# 1                                      store    0.172502       100.0
# 2                   f_weather_pca_0_94efd18d    0.056469       100.0
# 3                       f_week_sin1_a71d22f6    0.044848       100.0
# 4                       f_week_cos1_d3d56d7f    0.029807       100.0
# 5                 f_weather_umap_48_66a91289    0.025439       100.0
# 6                 f_weather_umap_24_409427e4    0.018721       100.0
# 7                 f_weather_umap_33_b9760f68    0.014879       100.0
# 8                       f_year_cos1_cd165f8c    0.011822       100.0
# 9                       f_dow_jones_89547e1d    0.007005       100.0
# 10                         f_silver_d4264cf9    0.005451       100.0
# 11                f_weather_umap_43_4e9820c4    0.004610       100.0
# 12                f_weather_umap_31_50ba2974    0.004423       100.0
# 13                f_weather_umap_35_436c04a5    0.004119       100.0
# 14                 f_finance_umap_3_424d51ca    0.003301       100.0
# 15                         f_snp500_61d23988    0.003259       100.0
# 16                      f_cpi_pca_5_db7798a3    0.003046       100.0
# 17                          f_stoxx_4ddb0c38    0.002794       100.0
# 18                 f_italy_game_cnt_9cfcfe65    0.002227       100.0
# 19            f_payment_fraud_score_b6a9c12e    0.002158       100.0
# 20    f_dow_jones_7d_to_7d_1y_shift_9628c89b    0.002075       100.0
# 21                f_weather_umap_34_39fc3e94    0.001923       100.0
# 22                f_silver_7d_to_1y_82c4ef86    0.001770       100.0
# 23                         f_nasdaq_d309709a    0.001754       100.0
# 24                   f_cbpol_umap_1_34dc2149    0.001570       100.0
# 25                f_weather_umap_45_b348f420    0.001454       100.0
# 26                f_c2c_fraud_score_5028232e    0.001401       100.0
# 27         f_mlending_approve_score_d4c33397    0.001351       100.0
# 28       f_silver_7d_to_7d_1y_shift_ccbd2abf    0.001350       100.0
# 29                   f_cbpol_umap_6_f175da9a    0.001327       100.0
# 30                    f_cbpol_pca_3_2e94b9bf    0.001231       100.0
# 31                     f_cpi_umap_4_83d3b2a6    0.001203       100.0
# 32  f_transaction_fraud_union_score_c1a2808b    0.001109       100.0
# 33             f_bank_approve_score_f3797f4b    0.001061       100.0
# 34                  f_gold_7d_to_1y_1df66550    0.000976       100.0
#
#          type
# 0   CHARACTER
# 1   CHARACTER
# 2     NUMERIC
# 3     NUMERIC
# 4     NUMERIC
# 5     NUMERIC
# 6     NUMERIC
# 7     NUMERIC
# 8     NUMERIC
# 9     NUMERIC
# 10    NUMERIC
# 11    NUMERIC
# 12    NUMERIC
# 13    NUMERIC
# 14    NUMERIC
# 15    NUMERIC
# 16    NUMERIC
# 17    NUMERIC
# 18    NUMERIC
# 19    NUMERIC
# 20    NUMERIC
# 21    NUMERIC
# 22    NUMERIC
# 23    NUMERIC
# 24    NUMERIC
# 25    NUMERIC
# 26    NUMERIC
# 27    NUMERIC
# 28    NUMERIC
# 29    NUMERIC
# 30    NUMERIC
# 31    NUMERIC
# 32    NUMERIC
# 33    NUMERIC
# 34    NUMERIC

# %% [markdown]
# ### <b><span style='color:#58A2A8'>5.3</span> | Model creation</b>

# %%
from catboost import CatBoostRegressor
from catboost.utils import eval_metric
model = CatBoostRegressor(verbose=False, allow_writing_files=False, random_state=0)

# Calculate metrics before and after enrichment with new relevant features
enricher.calculate_metrics(
    train_features, train_target, 
    eval_set = [(test_features, test_target)],
    estimator = model,
    scoring = "mean_absolute_percentage_error"
)
# Out:
# Calculating metrics...
# Done
#         match_rate  baseline mean_absolute_percentage_error  \
#
# train        100.0                                 0.255844
# eval 1       100.0                                 0.243877
#
#         enriched mean_absolute_percentage_error    uplift
#
# train                                  0.170663  0.085181
# eval 1                                 0.131175  0.112701

# %%
enriched_train_features = enricher.transform(train_features, keep_input = True)
enriched_test_features = enricher.transform(test_features, keep_input = True)
enriched_train_features.head()
# Out:
# WARNING: You have started the search with the DATE key only. Try to add the COUNTRY and/or POSTAL_CODE keys to your dataset so that the search engine gets access to the additional data sources. Get details on https://github.com/upgini/upgini#2--choose-one-or-multiple-columns-as-a-search-keys
# 90.39637% of the rows are fully duplicated
# <table><tr><th style='font-weight:bold'>Column name</th><th style='font-weight:bold'>Status</th><th style='font-weight:bold'>Description</th></tr><tr><td>date</td><td style='background-color:#DAF7A6;color:black'>All valid</td><td>All values in this column are good to go</td></tr></table>
# Running search request with search_id=03ec4887-97a2-4877-a6a6-81d92edffff0
# We'll send email notification once it's completed, just use your personal api_key from profile.upgini.com
# Done
#
# Collecting selected features...
# Done
# WARNING: You have started the search with the DATE key only. Try to add the COUNTRY and/or POSTAL_CODE keys to your dataset so that the search engine gets access to the additional data sources. Get details on https://github.com/upgini/upgini#2--choose-one-or-multiple-columns-as-a-search-keys
# 90.36176% of the rows are fully duplicated
# <table><tr><th style='font-weight:bold'>Column name</th><th style='font-weight:bold'>Status</th><th style='font-weight:bold'>Description</th></tr><tr><td>date</td><td style='background-color:#DAF7A6;color:black'>All valid</td><td>All values in this column are good to go</td></tr></table>
# Running search request with search_id=615b6326-2919-4dc5-baee-0c1114d73e59
# We'll send email notification once it's completed, just use your personal api_key from profile.upgini.com
# Done
#
# Collecting selected features...
# Done
#         date store item  f_weather_pca_0_94efd18d  f_week_sin1_a71d22f6  \
# 0 2013-01-01     7    5                 29.676683              0.781831
# 1 2013-01-01     4    9                 29.676683              0.781831
# 2 2013-01-01     1   33                 29.676683              0.781831
# 3 2013-01-01     3   41                 29.676683              0.781831
# 4 2013-01-01     5   24                 29.676683              0.781831
#
#    f_week_cos1_d3d56d7f  f_weather_umap_48_66a91289  \
# 0               0.62349                    4.540985
# 1               0.62349                    4.540985
# 2               0.62349                    4.540985
# 3               0.62349                    4.540985
# 4               0.62349                    4.540985
#
#    f_weather_umap_24_409427e4  f_weather_umap_33_b9760f68  \
# 0                    5.828106                    4.644803
# 1                    5.828106                    4.644803
# 2                    5.828106                    4.644803
# 3                    5.828106                    4.644803
# 4                    5.828106                    4.644803
#
#    f_year_cos1_cd165f8c  ...  f_weather_umap_45_b348f420  \
# 0               0.98522  ...                    4.923654
# 1               0.98522  ...                    4.923654
# 2               0.98522  ...                    4.923654
# 3               0.98522  ...                    4.923654
# 4               0.98522  ...                    4.923654
#
#    f_c2c_fraud_score_5028232e  f_mlending_approve_score_d4c33397  \
# 0                    0.285548                           0.338412
# 1                    0.285548                           0.338412
# 2                    0.285548                           0.338412
# 3                    0.285548                           0.338412
# 4                    0.285548                           0.338412
#
#    f_silver_7d_to_7d_1y_shift_ccbd2abf  f_cbpol_umap_6_f175da9a  \
# 0                             1.072025                 1.367325
# 1                             1.072025                 1.367325
# 2                             1.072025                 1.367325
# 3                             1.072025                 1.367325
# 4                             1.072025                 1.367325
#
#    f_cbpol_pca_3_2e94b9bf  f_cpi_umap_4_83d3b2a6  \
# 0               -0.323471              10.153208
# 1               -0.323471              10.153208
# 2               -0.323471              10.153208
# 3               -0.323471              10.153208
# 4               -0.323471              10.153208
#
#    f_transaction_fraud_union_score_c1a2808b  f_bank_approve_score_f3797f4b  \
# 0                                  0.057741                       0.332893
# 1                                  0.057741                       0.332893
# 2                                  0.057741                       0.332893
# 3                                  0.057741                       0.332893
# 4                                  0.057741                       0.332893
#
#    f_gold_7d_to_1y_1df66550
# 0                  0.994608
# 1                  0.994608
# 2                  0.994608
# 3                  0.994608
# 4                  0.994608
#
# [5 rows x 36 columns]

# %% [markdown]
# ## <div style="color:white;display:fill;border-radius:5px;background-color:#9DCDD1;overflow:hidden"><p style="padding:20px;color:white;overflow:hidden;font-size:100%;letter-spacing:0.5px;margin:0"><b>6 | Performance and Evaluation</b></div>

# %%
model.fit(train_features, train_target)
preds = model.predict(test_features)
eval_metric(test_target.values, preds, "SMAPE")
# Out:
# [37.65141857448004]

# %%
model.fit(enriched_train_features, train_target)
enriched_preds = model.predict(enriched_test_features)
eval_metric(test_target.values, enriched_preds, "SMAPE")
# Out:
# [14.520546401124]
