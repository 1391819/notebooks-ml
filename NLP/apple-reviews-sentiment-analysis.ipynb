# %% [markdown]
# <a href="https://colab.research.google.com/github/1391819/notebooks-ml/blob/main/NLP/apple-reviews-sentiment-analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # About
# Sentiment analysis using BeautifulSoup and TextBlob.
#
# ## Data
# - Extracted and collected business reviews from Apple's TrustPilot page
# - Created additional features from reviews for a more in-depth data analysis
#
# ## Stack
# - TextBlob
# - BeautifulSoup
# - Data Cleaning and Interpretation

# %% [markdown]
# ## Extracting and collecting business reviews

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %%
reviews = []

pages = np.arange(1, 5, 1)

for page in pages:
  page = requests.get("https://www.trustpilot.com/review/www.apple.com" + "?page=" + str(page))

  soup = BeautifulSoup(page.text, "html.parser")

  review_div = soup.find_all("div", class_="styles_reviewContent__0Q2Tg")

  for container in review_div:
    raw_content = container.find("p")
    reviews.append(raw_content.text)

# %% [markdown]
# ## Analysing the data

# %%
df = pd.DataFrame(np.array(reviews), columns=["review"])

# %%
len(df["review"])

# %%
df["word_count"] = df["review"].apply(lambda x: len(x.split()))

# %%
df["char_count"] = df["review"].apply(lambda x: len(x))

# %%
def average_words(x):
  words = x.split()
  return sum(len(word) for word in words) / len(words)

# %%
df["average_word_length"] = df["review"].apply(lambda x: average_words(x))

# %%
from nltk.corpus import stopwords

stop_words = stopwords.words("english")

df["stopword-count"] = df["review"].apply(lambda x: len([word for word in x.split() if word.lower() in stop_words]))

df["stopword-rate"] = df["stopword-count"] / df["word_count"]

# %%
df.sort_values(by="stopword-rate")
# Out:
#                                                review  word_count  char_count  \
# 45  Bought I Mac 4K in 2017 great at first now it’...          77         370
# 4   Apple sells very poor quality products.  I had...          36         195
# 20  Will never use apple again. Have always loved ...          65         344
# 68  Apple make terrible products that just don’t l...          69         401
# 26  apple iphone 7 support will stop in a month , ...         131         615
# ..                                                ...         ...         ...
# 40  If you have booked your appointment with servi...          86         423
# 36  I visited the Apple store today to have my Mac...         127         661
# 39  My review is about someone who has treated me ...          33         167
# 57  My AirPods were not working so when I worked w...         157         856
# 41  Customer service rep, had me change my setting...          46         231
#
#     average_word_length  stopword-count  stopword-rate
# 45             3.805195              23       0.298701
# 4              4.388889              11       0.305556
# 20             4.307692              22       0.338462
# 68             4.826087              24       0.347826
# 26             3.702290              47       0.358779
# ..                  ...             ...            ...
# 40             3.930233              48       0.558140
# 36             4.212598              73       0.574803
# 39             4.090909              19       0.575758
# 57             4.452229              91       0.579618
# 41             4.043478              27       0.586957
#
# [80 rows x 6 columns]

# %%
df.describe()
# Out:
#        word_count   char_count  average_word_length  stopword-count  \
# count   80.000000    80.000000            80.000000       80.000000
# mean    87.662500   473.387500             4.401452       39.862500
# std     52.097266   287.268299             0.343675       23.729885
# min     14.000000    77.000000             3.702290        7.000000
# 25%     58.750000   328.750000             4.209081       24.000000
# 50%     79.500000   409.500000             4.372685       35.000000
# 75%    102.250000   566.750000             4.616591       48.000000
# max    371.000000  1998.000000             5.225352      155.000000
#
#        stopword-rate
# count      80.000000
# mean        0.453038
# std         0.063197
# min         0.298701
# 25%         0.411502
# 50%         0.452425
# 75%         0.500000
# max         0.586957

# %% [markdown]
# ## Data cleaning
#
# - Removing redundant words (stop words, punctuation, etc.)

# %%
df.review
# Out:
# 0     I have received message from 20697 my iphone w...
# 1     Purchased a new MacBook Air a year ago & withi...
# 2     Longtime Apple user I’ve been lucky enough to ...
# 3     Apple won't help... I need to reset my securit...
# 4     Apple sells very poor quality products.  I had...
#                             ...
# 75    I am not sure how Apple grown this much when t...
# 76    I tried many methods on YouTube but no video c...
# 77    My iphone 6S finally crashed. I had insurance ...
# 78    I’ve had Apple technology for a long time. I s...
# 79    Short, sweet and to the point. Needed an Apple...
# Name: review, Length: 80, dtype: object

# %%
# Lower casing
df["lowercase"] = df["review"].apply(lambda x: " ".join(word.lower() for word in x.split()))

# %%
# Punctuation
df["punctuation"] = df["lowercase"].str.replace("[^\w\s]", "")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version.

# %%
# Stop words 
df["stopwords"] = df["punctuation"].apply(lambda x: " ".join(word for word in x.split() if word not in stop_words))

# %%
# Creating a frequency count to track recursive words
pd.Series(" ".join(df["stopwords"]).split()).value_counts()[:30]
# Out:
# apple       154
# phone        50
# customer     38
# iphone       34
# support      33
# service      32
# dont         32
# new          27
# years        24
# back         24
# never        23
# products     22
# time         19
# store        18
# buy          18
# use          18
# company      17
# 2            16
# im           16
# money        16
# problem      15
# would        15
# help         15
# 3            14
# call         14
# like         14
# could        14
# hours        14
# going        13
# get          13
# dtype: int64

# %%
other_stop_words = ["get", "told"] # a lot more can be added, testing required
df["cleaned_review"] = df["stopwords"].apply(lambda x: " ".join(word for word in x.split() if word not in other_stop_words))
pd.Series(" ".join(df["cleaned_review"]).split()).value_counts()[:30]
# Out:
# apple       154
# phone        50
# customer     38
# iphone       34
# support      33
# dont         32
# service      32
# new          27
# years        24
# back         24
# never        23
# products     22
# time         19
# use          18
# buy          18
# store        18
# company      17
# im           16
# money        16
# 2            16
# would        15
# help         15
# problem      15
# hours        14
# 3            14
# like         14
# call         14
# could        14
# going        13
# one          12
# dtype: int64

# %%
df.head()
# Out:
#                                               review  word_count  char_count  \
# 0  I have received message from 20697 my iphone w...          71         441
# 1  Purchased a new MacBook Air a year ago & withi...          57         329
# 2  Longtime Apple user I’ve been lucky enough to ...          93         514
# 3  Apple won't help... I need to reset my securit...          80         406
# 4  Apple sells very poor quality products.  I had...          36         195
#
#    average_word_length  stopword-count  stopword-rate  \
# 0             5.225352              34       0.478873
# 1             4.789474              23       0.403509
# 2             4.526882              42       0.451613
# 3             4.087500              32       0.400000
# 4             4.388889              11       0.305556
#
#                                            lowercase  \
# 0  i have received message from 20697 my iphone w...
# 1  purchased a new macbook air a year ago & withi...
# 2  longtime apple user i’ve been lucky enough to ...
# 3  apple won't help... i need to reset my securit...
# 4  apple sells very poor quality products. i had ...
#
#                                          punctuation  \
# 0  i have received message from 20697 my iphone w...
# 1  purchased a new macbook air a year ago  within...
# 2  longtime apple user ive been lucky enough to n...
# 3  apple wont help i need to reset my security qu...
# 4  apple sells very poor quality products i had a...
#
#                                            stopwords  \
# 0  received message 20697 iphone snatched 15augus...
# 1  purchased new macbook air year ago within firs...
# 2  longtime apple user ive lucky enough need supp...
# 3  apple wont help need reset security questions ...
# 4  apple sells poor quality products macbook air ...
#
#                                       cleaned_review
# 0  received message 20697 iphone snatched 15augus...
# 1  purchased new macbook air year ago within firs...
# 2  longtime apple user ive lucky enough need supp...
# 3  apple wont help need reset security questions ...
# 4  apple sells poor quality products macbook air ...

# %% [markdown]
# ## Lemmatization using TextBlob

# %%
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')

from textblob import Word
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
df["lemmatized"] = df["cleaned_review"].apply(lambda x: " ".join(Word(word).lemmatize() for word in x.split()))

# %% [markdown]
# ## Sentiment Analysis

# %%
from textblob import TextBlob

# %%
# polarity and subjectivity metrics -> returned by TextBlob
# polarity: negative (-1) or positive (+1) a review is 
# subjectivity: generic opinion vs factual information 
df["polarity"] = df["lemmatized"].apply(lambda x: TextBlob(x).sentiment[0])
df["subjectivity"] = df["lemmatized"].apply(lambda x: TextBlob(x).sentiment[1])

# %%
df.drop(["lowercase", "punctuation", "stopwords", "cleaned_review", "lemmatized"], axis=1, inplace = True)

# %%
df.describe()
# Out:
#        word_count   char_count  average_word_length  stopword-count  \
# count   80.000000    80.000000            80.000000       80.000000
# mean    87.662500   473.387500             4.401452       39.862500
# std     52.097266   287.268299             0.343675       23.729885
# min     14.000000    77.000000             3.702290        7.000000
# 25%     58.750000   328.750000             4.209081       24.000000
# 50%     79.500000   409.500000             4.372685       35.000000
# 75%    102.250000   566.750000             4.616591       48.000000
# max    371.000000  1998.000000             5.225352      155.000000
#
#        stopword-rate   polarity  subjectivity
# count      80.000000  80.000000     80.000000
# mean        0.453038   0.001603      0.480444
# std         0.063197   0.265305      0.212866
# min         0.298701  -0.816667      0.000000
# 25%         0.411502  -0.129911      0.365278
# 50%         0.452425   0.000000      0.473990
# 75%         0.500000   0.175694      0.598295
# max         0.586957   1.000000      1.000000

# %% [markdown]
# Dealing with relatively negative reviews (mean = 0.001603).

# %%
df.sort_values(by="polarity")
# Out:
#                                                review  word_count  char_count  \
# 11  Really bad camera for iphone 13, I’m so disapp...          27         151
# 24  Moved countries and will not let me reset pass...          79         404
# 6   Any Apple device is bulls*it, upgrade to iOS 1...          41         228
# 19  Just wanted to say how pathetic it was that I ...          55         294
# 61  I call for support get no support they have ve...          29         153
# ..                                                ...         ...         ...
# 2   Longtime Apple user I’ve been lucky enough to ...          93         514
# 36  I visited the Apple store today to have my Mac...         127         661
# 64  I would give a zero if I could, I ordered some...         101         507
# 27  The presentation of their items is superb. loo...          14          77
# 47  My screen was working perfectly until I upgrad...          17          86
#
#     average_word_length  stopword-count  stopword-rate  polarity  subjectivity
# 11             4.629630              10       0.370370 -0.816667      0.805556
# 24             4.126582              43       0.544304 -0.600000      0.900000
# 6              4.585366              15       0.365854 -0.496212      0.818182
# 19             4.363636              27       0.490909 -0.466667      0.366667
# 61             4.310345              11       0.379310 -0.437500      0.700000
# ..                  ...             ...            ...       ...           ...
# 2              4.526882              42       0.451613  0.259259      0.487037
# 36             4.212598              73       0.574803  0.320000      0.420000
# 64             4.029703              53       0.524752  0.328571      0.378571
# 27             4.571429               7       0.500000  0.900000      0.875000
# 47             4.117647               8       0.470588  1.000000      1.000000
#
# [80 rows x 8 columns]
